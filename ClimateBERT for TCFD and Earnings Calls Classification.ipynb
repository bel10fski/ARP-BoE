# %% [markdown]
# # ClimateBERT for TCFD and Earnings Calls Classification
#
# ### ClimateBERT (https://huggingface.co/climatebert) is a specialised language pre-trained model fine-tuned for analyzing climate-related texts. It has been employed to classify both TCFD (Task Force on Climate-related Financial Disclosures) reports and earnings calls for ST. JAMES place & Traveler Cos TRV. The classification helps in identifying and categorizing climate-related information.

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Loading and Reading Data for TCFD and Earnings Calls Classification

# %%
# File paths for the CSV files
tcfd_traveler_path = 'tcfd_company_csvs\Traveler_Cos_tcfd_df.csv'
tcfd_st_james_path = 'tcfd_company_csvs\St_James_tcfd_df.csv'
earnings_traveler_path = 'company_csvs\Travelers_Cos_df.csv'
earnings_st_james_path = 'company_csvs\St_Jamess_df.csv'

# Reading the CSV files into DataFrames
tcfd_traveler_df = pd.read_csv(tcfd_traveler_path)
tcfd_st_james_df = pd.read_csv(tcfd_st_james_path)
earnings_traveler_df = pd.read_csv(earnings_traveler_path)
earnings_st_james_df = pd.read_csv(earnings_st_james_path)

# %% [markdown]
# ## TCFD Reports
# The pre-trained model used for TCFD classification is `climatebert/distilroberta-base-climate-tcfd`. This fine-tuned ClimateBERT language model includes a classification head specifically designed to categorize climate-related paragraphs into the four TCFD recommendation categories.The model was trained on paragraphs extracted from corporate annual reports and sustainability reports. The labels used are:
# - 0 -> None (i.e., not climate-related)
# - 1 -> Metrics
# - 2 -> Strategy
# - 3 -> Risk
# - 4 -> Governance

# %% [markdown]
# ```bibtex
# @techreport{bingler2023cheaptalk,
#     title       = {How Cheap Talk in Climate Disclosures Relates to Climate Initiatives, Corporate Emissions, and Reputation Risk},
#     author      = {Bingler, Julia and Kraus, Mathias and Leippold, Markus and Webersinke, Nicolas},
#     type        = {Working paper},
#     institution = {Available at SSRN 3998435},
#     year        = {2023}
# }

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Load the ClimateBERT model
model_name = "climatebert/distilroberta-base-climate-tcfd"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Define the mapping of numeric labels to TCFD categories
label_mapping = {
    0: "none",
    1: "metrics",
    2: "strategy",
    3: "risk",
    4: "governance"
}

# Define a function to classify text using the ClimateBERT model
def classify_text(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    predicted_class_id = torch.argmax(logits, dim=1).item()
    label_name = label_mapping[predicted_class_id]
    return predicted_class_id, label_name

# Apply the classification function to the 'paragraph' column
classification_results_st_james = tcfd_st_james_df['paragraph'].apply(classify_text)
classification_results_traveler = tcfd_traveler_df['paragraph'].apply(classify_text)

# Split the results into two separate columns
tcfd_st_james_df['tcfd_classification_id'] = classification_results_st_james.apply(lambda x: x[0])
tcfd_st_james_df['tcfd_classification_label'] = classification_results_st_james.apply(lambda x: x[1])

tcfd_traveler_df['tcfd_classification_id'] = classification_results_traveler.apply(lambda x: x[0])
tcfd_traveler_df['tcfd_classification_label'] = classification_results_traveler.apply(lambda x: x[1])

# %%
tcfd_traveler_df
# Out:
#                                file_name  date  \
# 0   cleaned_Travelers_TCFDReport2019.txt  2019
# 1   cleaned_Travelers_TCFDReport2019.txt  2019
# 2   cleaned_Travelers_TCFDReport2019.txt  2019
# 3   cleaned_Travelers_TCFDReport2019.txt  2019
# 4   cleaned_Travelers_TCFDReport2019.txt  2019
# 5   cleaned_Travelers_TCFDReport2019.txt  2019
# 6   cleaned_Travelers_TCFDReport2020.txt  2020
# 7   cleaned_Travelers_TCFDReport2020.txt  2020
# 8   cleaned_Travelers_TCFDReport2020.txt  2020
# 9   cleaned_Travelers_TCFDReport2020.txt  2020
# 10  cleaned_Travelers_TCFDReport2020.txt  2020
# 11  cleaned_Travelers_TCFDReport2020.txt  2020
# 12  cleaned_Travelers_TCFDReport2020.txt  2020
# 13  cleaned_Travelers_TCFDReport2021.txt  2021
# 14  cleaned_Travelers_TCFDReport2021.txt  2021
# 15  cleaned_Travelers_TCFDReport2021.txt  2021
# 16  cleaned_Travelers_TCFDReport2021.txt  2021
# 17  cleaned_Travelers_TCFDReport2021.txt  2021
# 18  cleaned_Travelers_TCFDReport2021.txt  2021
# 19  cleaned_Travelers_TCFDReport2021.txt  2021
# 20  cleaned_Travelers_TCFDReport2021.txt  2021
# 21  cleaned_Travelers_TCFDReport2021.txt  2021
# 22  cleaned_Travelers_TCFDReport2021.txt  2021
# 23  cleaned_Travelers_TCFDReport2021.txt  2021
# 24  cleaned_Travelers_TCFDReport2021.txt  2021
# 25  cleaned_Travelers_TCFDReport2021.txt  2021
# 26  cleaned_Travelers_TCFDReport2021.txt  2021
# 27  cleaned_Travelers_TCFDReport2022.txt  2022
# 28  cleaned_Travelers_TCFDReport2022.txt  2022
# 29  cleaned_Travelers_TCFDReport2022.txt  2022
# 30  cleaned_Travelers_TCFDReport2022.txt  2022
# 31  cleaned_Travelers_TCFDReport2022.txt  2022
# 32  cleaned_Travelers_TCFDReport2022.txt  2022
# 33  cleaned_Travelers_TCFDReport2022.txt  2022
# 34  cleaned_Travelers_TCFDReport2022.txt  2022
# 35  cleaned_Travelers_TCFDReport2022.txt  2022
# 36  cleaned_Travelers_TCFDReport2022.txt  2022
# 37  cleaned_Travelers_TCFDReport2022.txt  2022
# 38  cleaned_Travelers_TCFDReport2022.txt  2022
# 39  cleaned_Travelers_TCFDReport2022.txt  2022
# 40  cleaned_Travelers_TCFDReport2022.txt  2022
# 41  cleaned_Travelers_TCFDReport2023.txt  2023
# 42  cleaned_Travelers_TCFDReport2023.txt  2023
# 43  cleaned_Travelers_TCFDReport2023.txt  2023
# 44  cleaned_Travelers_TCFDReport2023.txt  2023
# 45  cleaned_Travelers_TCFDReport2023.txt  2023
# 46  cleaned_Travelers_TCFDReport2023.txt  2023
# 47  cleaned_Travelers_TCFDReport2023.txt  2023
# 48  cleaned_Travelers_TCFDReport2023.txt  2023
# 49  cleaned_Travelers_TCFDReport2023.txt  2023
# 50  cleaned_Travelers_TCFDReport2023.txt  2023
# 51  cleaned_Travelers_TCFDReport2023.txt  2023
# 52  cleaned_Travelers_TCFDReport2023.txt  2023
# 53  cleaned_Travelers_TCFDReport2023.txt  2023
# 54  cleaned_Travelers_TCFDReport2023.txt  2023
#
#                                                 token  \
# 0   ['casualty', 'understand', 'role', 'organizati...
# 1   ['potential', 'causal', 'variability', 'people...
# 2   ['opportunity', 'conduct', 'evaluation', 'viab...
# 3   ['protect', 'portion', 'review', 'program', 't...
# 4   ['consistency', 'underwrite', 'authority', 'au...
# 5   ['scope', 'revenue', 'person', 'scope', 'trave...
# 6   ['casualty', 'understand', 'core', 'price', 'm...
# 7   ['rule', 'greenhouse', 'gas', 'coal', 'steam',...
# 8   ['disclosure', 'scenario', 'technology', 'subj...
# 9   ['judgment', 'subject', 'result', 'volatility'...
# 10  ['discount', 'hull', 'eligibility', 'discount'...
# 11  ['work', 'review', 'coverage', 'report', 'rewa...
# 12  ['greenhouse', 'gas', 'topic', 'metric', 'metr...
# 13  ['government', 'experience', 'frequency', 'int...
# 14  ['gas', 'field', 'classification', 'power', 'p...
# 15  ['result', 'activity', 'asset', 'medium', 'fut...
# 16  ['innovation', 'demand', 'opportunity', 'growt...
# 17  ['confidence', 'direction', 'magnitude', 'chan...
# 18  ['growth', 'wildfire', 'suite', 'coverage', 'g...
# 19  ['indication', 'comparison', 'basis', 'casualt...
# 20  ['enterprise', 'operate', 'consumption', 'wast...
# 21  ['habitat', 'wildlife', 'effort', 'footprint',...
# 22  ['opportunity', 'organization', 'determination...
# 23  ['capital', 'extent', 'phase', 'dust', 'influe...
# 24  ['commitment', 'achieve', 'dioxide', 'plan', '...
# 25  ['reliability', 'power', 'service', 'territory...
# 26  ['track', 'total', 'insure', 'insure', 'chart'...
# 27  ['severity', 'wildfire', 'frequency', 'severit...
# 28  ['survey', 'shoot', 'oil', 'gas', 'field', 'cl...
# 29  ['water', 'quality', 'price', 'air', 'water', ...
# 30  ['availability', 'lead', 'automobile', 'hybrid...
# 31  ['leader', 'scenario', 'visibility', 'scenario...
# 32  ['coverage', 'behavior', 'adoption', 'construc...
# 33  ['test', 'mind', 'indication', 'comparison', '...
# 34  ['outlook', 'season', 'wildfire', 'mitigation'...
# 35  ['usage', 'conservation', 'group', 'fund', 'pl...
# 36  ['scenario', 'subcommittee', 'subject', 'matte...
# 37  ['account', 'range', 'probability', 'modeling'...
# 38  ['unrest', 'wildfire', 'storm', 'winter', 'sto...
# 39  ['statistic', 'reduction', 'weight', 'weight',...
# 40  ['invest', 'operate', 'utility', 'scale', 'dev...
# 41  ['frequency', 'severity', 'wildfire', 'period'...
# 42  ['surveying', 'core', 'slush', 'oil', 'gas', '...
# 43  ['capital', 'prevention', 'safety', 'regulatio...
# 44  ['cost', 'audit', 'deduction', 'deduction', 'b...
# 45  ['category', 'size', 'track', 'storm', 'litera...
# 46  ['composition', 'table', 'breakdown', 'rating'...
# 47  ['proceed', 'fund', 'variety', 'bond', 'graph'...
# 48  ['utility', 'review', 'incentive', 'fund', 'te...
# 49  ['conservation', 'habitat', 'wildlife', 'effor...
# 50  ['premium', 'underwrite', 'casualty', 'evaluat...
# 51  ['government', 'modeling', 'frequency', 'inten...
# 52  ['commitment', 'plan', 'goal', 'implement', 'r...
# 53  ['remainder', 'decline', 'measure', 'enterpris...
# 54  ['view', 'write', 'premium', 'fossil', 'fuel',...
#
#                                             paragraph  tcfd_classification_id  \
# 0   Severe weather over the last two have the of f...                       0
# 1   other of senior management to discuss that cou...                       0
# 2   environment which can also reduce our operatin...                       0
# 3   Risk Committee and the other of the Board our ...                       0
# 4   diagram below the comprehensive approach we ta...                       0
# 5   and that extend beyond the short and medium te...                       2
# 6   Severe weather over the last two have the of f...                       2
# 7   our operational impact on the environment whic...                       2
# 8   potential to climate The Risk Committee of the...                       0
# 9   Committee the implementation execution and per...                       0
# 10  and climate related and across and is a venue ...                       0
# 11  on ongoing or transition Development of new or...                       2
# 12  example from time to time pass legislation and...                       2
# 13  additional uncertainty as to future and Climat...                       2
# 14  climate related Moreover is to a long term sus...                       2
# 15  this report should not be as a characterizatio...                       2
# 16  come primarily from the ongoing and promising ...                       2
# 17  energy industry with insurance coverage will n...                       2
# 18  Energy Sector The energy sector is one of many...                       2
# 19  use transmission to transport such as crude oi...                       2
# 20  gas field gathering Due to industry classifica...                       2
# 21  Board of and its Risk Committee consider clima...                       0
# 22  loss experience loss trend learned from recent...                       0
# 23  climate A senior executive team which the Chie...                       0
# 24  a range of time TIME HORIZON CLIMATE TRANSITIO...                       2
# 25  related for each time horizon The geographic d...                       2
# 26  that participate in residual Participation in ...                       2
# 27  of climate For example the frequency and or se...                       2
# 28  the and by climate to provide and that both he...                       2
# 29  analyses indicate that other such as demograph...                       2
# 30  energy at utility scale electricity generation...                       2
# 31  of net zero we believe that through the provis...                       2
# 32  Practice we are prepared to continue to suppor...                       2
# 33  MIDSTREAM that use transmission to transport s...                       2
# 34  market that Provide support for the mining and...                       2
# 35  sheet and identify and avail ourselves of clim...                       0
# 36  climate These include for example information ...                       0
# 37  strong culture of risk management with respect...                       0
# 38  climate related risk Strategy Climate related ...                       2
# 39  our Risk Control Climate The following are of ...                       1
# 40  such as legislation from reducing or withdrawi...                       2
# 41  Severe weather over the last two have the of c...                       2
# 42  core to our business Accordingly we continuall...                       2
# 43  to note that as important as climate is to our...                       2
# 44  significant majority of the overall energy mix...                       2
# 45  assist in the energy transition Especially in ...                       2
# 46  in the climate problem Through our Global Rene...                       2
# 47  They may operate generation that produce elect...                       2
# 48  electricity and or electricity Due to industry...                       2
# 49  and doing our part to assist in the transition...                       0
# 50  The Board Risk Committee on a quarterly basis ...                       0
# 51  responsibility for the oversight of strategic ...                       0
# 52  Committee and is a member of the Company s Dis...                       0
# 53  e g climate related risk energy consumption en...                       2
# 54  in response to potential in climate may impact...                       2
#
#    tcfd_classification_label
# 0                       none
# 1                       none
# 2                       none
# 3                       none
# 4                       none
# 5                   strategy
# 6                   strategy
# 7                   strategy
# 8                       none
# 9                       none
# 10                      none
# 11                  strategy
# 12                  strategy
# 13                  strategy
# 14                  strategy
# 15                  strategy
# 16                  strategy
# 17                  strategy
# 18                  strategy
# 19                  strategy
# 20                  strategy
# 21                      none
# 22                      none
# 23                      none
# 24                  strategy
# 25                  strategy
# 26                  strategy
# 27                  strategy
# 28                  strategy
# 29                  strategy
# 30                  strategy
# 31                  strategy
# 32                  strategy
# 33                  strategy
# 34                  strategy
# 35                      none
# 36                      none
# 37                      none
# 38                  strategy
# 39                   metrics
# 40                  strategy
# 41                  strategy
# 42                  strategy
# 43                  strategy
# 44                  strategy
# 45                  strategy
# 46                  strategy
# 47                  strategy
# 48                  strategy
# 49                      none
# 50                      none
# 51                      none
# 52                      none
# 53                  strategy
# 54                  strategy

# %%
tcfd_st_james_df
# Out:
#                                 file_name  date  \
# 0   cleaned_sjp-tcfd-report-april2020.txt  2020
# 1   cleaned_sjp-tcfd-report-april2020.txt  2020
# 2   cleaned_sjp-tcfd-report-april2021.txt  2021
# 3   cleaned_sjp-tcfd-report-april2021.txt  2021
# 4   cleaned_sjp-tcfd-report-april2021.txt  2021
# 5   cleaned_sjp-tcfd-report-april2021.txt  2021
# 6        cleaned_SJP_TCFD_Report_2022.txt  2022
# 7        cleaned_SJP_TCFD_Report_2022.txt  2022
# 8        cleaned_SJP_TCFD_Report_2022.txt  2022
# 9        cleaned_SJP_TCFD_Report_2022.txt  2022
# 10       cleaned_SJP_TCFD_Report_2022.txt  2022
# 11              cleaned_SJP_TCFD_2023.txt  2023
# 12              cleaned_SJP_TCFD_2023.txt  2023
# 13              cleaned_SJP_TCFD_2023.txt  2023
# 14              cleaned_SJP_TCFD_2023.txt  2023
# 15              cleaned_SJP_TCFD_2023.txt  2023
# 16              cleaned_SJP_TCFD_2023.txt  2023
# 17              cleaned_SJP_TCFD_2023.txt  2023
#
#                                                 token  \
# 0   ['time', 'summary', 'overview', 'roe', 'medium...
# 1   ['shape', 'response', 'area', 'monitor', 'moni...
# 2   ['desire', 'head', 'factor', 'introduction', '...
# 3   ['campaign', 'campaign', 'environment', 'corru...
# 4   ['statement', 'understand', 'inv', 'range', 'i...
# 5   ['assurance', 'day', 'basis', 'indication', 'p...
# 6   ['address', 'introduction', 'statement', 'pare...
# 7   ['nature', 'face', 'head', 'investor', 'shift'...
# 8   ['response', 'pathway', 'universe', 'estate', ...
# 9   ['integration', 'principe', 'coupe', 'sign', '...
# 10  ['permission', 'intensity', 'time', 'revenue',...
# 11  ['unit', 'trust', 'singe', 'subsidiary', 'text...
# 12  ['initiative', 'aim', 'exercise', 'protect', '...
# 13  ['manifest', 'timing', 'innovation', 'hand', '...
# 14  ['party', 'meet', 'frequency', 'matter', 'matr...
# 15  ['shape', 'boarding', 'party', 'basis', 'integ...
# 16  ['consumption', 'hope', 'heat', 'pus', 'purcha...
# 17  ['efficiency', 'water', 'efficiency', 'propone...
#
#                                             paragraph  tcfd_classification_id  \
# 0   Committee s of the Net St s Pace Report 2020 a...                       2
# 1   s Pace over the short medium and term Describe...                       2
# 2   46 to our 2021 report to St s Pace Group s rep...                       2
# 3   this backdrop we must innovate and back better...                       2
# 4   the ways we respect and care about and the wor...                       2
# 5   key risk facing the sector Therefore we have a...                       0
# 6   change is fast becoming one our It is a that f...                       0
# 7   38 within our Risk chapter found in the report...                       2
# 8   take action to identify measure and manage and...                       2
# 9   for 1 5 and in with Carbon for Partnership Com...                       2
# 10  the impact of change on our business how it ma...                       2
# 11  approach We are to our wi have a effect over t...                       1
# 12  in of the devastating effects of our Research ...                       2
# 13  term for our we consider throughout our and we...                       2
# 14  carbon impact is dominated by our investment O...                       2
# 15  55 report on the business how it may we make a...                       2
# 16  We have considered and our short medium and te...                       1
# 17  which we pan to Governing governance governanc...                       0
#
#    tcfd_classification_label
# 0                   strategy
# 1                   strategy
# 2                   strategy
# 3                   strategy
# 4                   strategy
# 5                       none
# 6                       none
# 7                   strategy
# 8                   strategy
# 9                   strategy
# 10                  strategy
# 11                   metrics
# 12                  strategy
# 13                  strategy
# 14                  strategy
# 15                  strategy
# 16                   metrics
# 17                      none

# %% [markdown]
# ## Earnings Calls

# %% [markdown]
# ### Climate Detection
# The `climatebert/distilroberta-base-climate-detector`pre-trained model is used for detecting climate-related paragraphs in earnings calls. This model, also fine-tuned from ClimateBERT, classifies paragraphs based on whether they are related to climate or not. It was trained on texts extracted from corporate annual reports and sustainability reports with the following labels:
# - 0 -> Not climate-related
# - 1 -> Climate-related

# %% [markdown]
# ```bibtex
# @techreport{bingler2023cheaptalk,
#     title        = {How Cheap Talk in Climate Disclosures Relates to Climate Initiatives, Corporate Emissions, and Reputation Risk},
#     author       = {Bingler, Julia and Kraus, Mathias and Leippold, Markus and Webersinke, Nicolas},
#     type         = {Working paper},
#     institution  = {Available at SSRN 3998435},
#     year         = {2023}
# }

# %% [markdown]
# The code truncates paragraphs that exceed the model's maximum token length. This ensures the model's capabilities are not exceeded, and only appropriately sized paragraphs are classified.

# %%
# Load the tokenizer and model
detector_model_name = "climatebert/distilroberta-base-climate-detector"
detector_tokenizer = AutoTokenizer.from_pretrained(detector_model_name)
detector_model = AutoModelForSequenceClassification.from_pretrained(detector_model_name)

# Initialize the pipeline
detector_pipeline = pipeline("text-classification", model=detector_model, tokenizer=detector_tokenizer, truncation=True)

# Define a function to classify paragraphs, with truncation for long paragraphs
def classify_paragraph(paragraph):
    # Truncate the paragraph if it is longer than the model's max length
    max_length = detector_tokenizer.model_max_length
    tokens = detector_tokenizer.tokenize(paragraph)
    if len(tokens) > max_length:
        return 'skipped', None
    result = detector_pipeline(paragraph)
    label = result[0]['label']  # Get the label directly as string
    score = result[0]['score']
    return label, score

# Apply the classification to the earnings calls dataframes
def apply_climate_detector(df):
    df['climate_label'], df['climate_score'] = zip(*df['paragraph'].apply(classify_paragraph))
    df['label_name'] = df.apply(lambda row: 'Yes' if row['climate_score'] and row['climate_score'] > 0.99 else 'No', axis=1)
    return df

# Apply the classification to both datasets
earnings_st_james_df = apply_climate_detector(earnings_st_james_df)
earnings_traveler_df = apply_climate_detector(earnings_traveler_df)

# Remove paragraphs with 'No' in label_name
earnings_st_james_df = earnings_st_james_df[earnings_st_james_df['label_name'] == 'Yes']
earnings_traveler_df = earnings_traveler_df[earnings_traveler_df['label_name'] == 'Yes']

# Remove the 'label_name' column
earnings_st_james_df = earnings_st_james_df.drop(columns=['label_name'])
earnings_traveler_df = earnings_traveler_df.drop(columns=['label_name'])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (537 > 512). Running this sequence through the model will result in indexing errors

# %%
earnings_st_james_df
# Out:
#                                              file_name        date  \
# 0    cleaned_St James_s Place PLC Earnings Call 201...  2019-07-31
# 1    cleaned_St James_s Place PLC Earnings Call 201...  2019-07-31
# 2    cleaned_St James_s Place PLC Earnings Call 201...  2019-07-31
# 3    cleaned_St James_s Place PLC Earnings Call 201...  2019-07-31
# 4    cleaned_St James_s Place PLC Earnings Call 201...  2019-07-31
# ..                                                 ...         ...
# 838  cleaned_St James_s Place PLC Earnings Call 202...  2024-02-28
# 840  cleaned_St James_s Place PLC Earnings Call 202...  2024-02-28
# 841  cleaned_St James_s Place PLC Earnings Call 202...  2024-02-28
# 842  cleaned_St James_s Place PLC Earnings Call 202...  2024-02-28
# 843  cleaned_St James_s Place PLC Earnings Call 202...  2024-02-28
#
#                                                  token  \
# 0     ['format', 'ﬁnancial', 'development', 'outlook']
# 1    ['uncertainty', 'trade', 'relationship', 'weal...
# 2    ['track', 'record', 'start', 'track', 'record'...
# 3    ['relationship', 'introduction', 'life', 'jour...
# 4    ['bonus', 'proceed', 'disposal', 'sale', 'indi...
# ..                                                 ...
# 838  ['activity', 'activity', 'activity', 'wealth',...
# 840  ['suspicion', 'hope', 'expectation', 'shoot', ...
# 841  ['piece', 'complaint', 'report', 'account', 'c...
# 842                             ['oﬀ', 'hour', 'chat']
# 843  ['announcement', 'challenge', 'priority', 'sig...
#
#                                              paragraph climate_label  \
# 0    Should we get started? So good morning, everyo...            no
# 1    So the ﬁrst six months. It's fair to say that ...            no
# 2    Importantly, the continued strong retention of...            no
# 3    So why is this? Well ﬁrst and foremost, St. Ja...            no
# 4    Where gross ﬂows can be impacted is with discr...            no
# ..                                                 ...           ...
# 838  Greg, thank you. I'll -- why don't I start wit...            no
# 840  And my personal suspicion is rates will come d...           yes
# 841  Craig, on the miscellaneous costs and the gest...            no
# 842  Craig, thank you for that -- thank you for tho...            no
# 843  I know there's been a lot to digest in this mo...            no
#
#      climate_score
# 0         0.995418
# 1         0.992183
# 2         0.995531
# 3         0.995329
# 4         0.994742
# ..             ...
# 838       0.993252
# 840       0.994948
# 841       0.991818
# 842       0.994778
# 843       0.996069
#
# [719 rows x 6 columns]

# %%
earnings_traveler_df
# Out:
#                                               file_name        date  \
# 0     cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 1     cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 2     cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 3     cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 7     cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# ...                                                 ...         ...
# 1379  cleaned_Travelers Cos IncThe Earnings Call 202...  2024-04-17
# 1380  cleaned_Travelers Cos IncThe Earnings Call 202...  2024-04-17
# 1381  cleaned_Travelers Cos IncThe Earnings Call 202...  2024-04-17
# 1382  cleaned_Travelers Cos IncThe Earnings Call 202...  2024-04-17
# 1385  cleaned_Travelers Cos IncThe Earnings Call 202...  2024-04-17
#
#                                                   token  \
# 0     ['completion', 'remark', 'instruction', 'sessi...
# 1     ['press', 'release', 'supplement', 'webcast', ...
# 2     ['attention', 'note', 'webcast', 'statement', ...
# 3     ['tort', 'expectation', 'minute', 'execution',...
# 7     ['disruption', 'success', 'center', 'strategy'...
# ...                                                 ...
# 1379  ['implication', 'box', 'magnitude', 'evaluation']
# 1380                ['slowdown', 'dynamic', 'slowdown']
# 1381        ['underwriting', 'takeaway', 'integration']
# 1382  ['capability', 'organization', 'quality', 'pro...
# 1385                    ['closing', 'remark', 'follow']
#
#                                               paragraph climate_label  \
# 0     Good morning, ladies and gentlemen. Welcome to...            no
# 1     At this time, I would like to turn the confere...            no
# 2     Before I turn the call over to Alan, I would l...            no
# 3     As I shared at an industry conference last mon...            no
# 7     As you'll hear from Greg, new business in our ...            no
# ...                                                 ...           ...
# 1379  Hey, Michael, it's Dan. I guess I'll say if yo...            no
# 1380  Hey, thanks. So we saw some data potentially i...            no
# 1381  Okay, got it. And maybe secondly, I'm curious ...            no
# 1382  We're feeling really good about bringing and l...            no
# 1385  Thank you. I will turn the call to Ms. Goldste...            no
#
#       climate_score
# 0          0.996929
# 1          0.996101
# 2          0.993522
# 3          0.995475
# 7          0.995973
# ...             ...
# 1379       0.993929
# 1380       0.994480
# 1381       0.994186
# 1382       0.995209
# 1385       0.995459
#
# [877 rows x 6 columns]

# %% [markdown]
# The code counts the occurrences of 'yes' and 'no' climate labels for St. James and Traveler, outputting the respective counts for each company.

# %%
# Count occurrences of 'yes', 'no' for St. James
counts_st_james = earnings_st_james_df['climate_label'].value_counts()

yes_count_st_james = counts_st_james.get('yes', 0)
no_count_st_james = counts_st_james.get('no', 0)

print(f"St. James - Yes: {yes_count_st_james}, No: {no_count_st_james},")

# Count occurrences of 'yes', 'no' for Traveler
counts_traveler = earnings_traveler_df['climate_label'].value_counts()

yes_count_traveler = counts_traveler.get('yes', 0)
no_count_traveler = counts_traveler.get('no', 0)

print(f"Traveler - Yes: {yes_count_traveler}, No: {no_count_traveler}")
# Out:
# St. James - Yes: 19, No: 700,
# Traveler - Yes: 70, No: 807

# %% [markdown]
# The code removes the rows with 'no' climate labels and the 'climate_label' and 'climate_score' columns, retaining only the rows with 'yes' climate labels.

# %%
# Filter the DataFrames to keep only the 'yes' rows and remove 'climate_label' and 'climate_score' columns
earnings_st_james_yes_df = earnings_st_james_df[earnings_st_james_df['climate_label'] == 'yes'].copy().drop(columns=['climate_label', 'climate_score']).reset_index(drop=True)
earnings_traveler_yes_df = earnings_traveler_df[earnings_traveler_df['climate_label'] == 'yes'].copy().drop(columns=['climate_label', 'climate_score']).reset_index(drop=True)

# %% [markdown]
# ### Sentiment Classification
# For classifying the sentiment of climate-related paragraphs, `climatebert/distilroberta-base-climate-sentiment` is used. The model is trained on climate-related paragraphs extracted from corporate annual reports and sustainability reports and uses the following climate-related sentiment labels:
# - 0 -> Risk
# - 1 -> Neutral
# - 2 -> Opportunity

# %% [markdown]
# ```bibtex
# @techreport{bingler2023cheaptalk,
#     title        = {How Cheap Talk in Climate Disclosures Relates to Climate Initiatives, Corporate Emissions, and Reputation Risk},
#     author       = {Bingler, Julia and Kraus, Mathias and Leippold, Markus and Webersinke, Nicolas},
#     type         = {Working paper},
#     institution  = {Available at SSRN 3998435},
#     year         = {2023}
# }

# %% [markdown]
# The code truncates paragraphs that exceed the model's maximum token length. This ensures the model's capabilities are not exceeded, and only appropriately sized paragraphs are classified.

# %%
# Load the tokenizer and model for climatebert/distilroberta-base-climate-sentiment
sentiment_model_name = "climatebert/distilroberta-base-climate-sentiment"
sentiment_tokenizer = AutoTokenizer.from_pretrained(sentiment_model_name)
sentiment_model = AutoModelForSequenceClassification.from_pretrained(sentiment_model_name)

# Initialize the pipeline
sentiment_pipeline = pipeline("text-classification", model=sentiment_model, tokenizer=sentiment_tokenizer, truncation=True)

# Define a function to classify paragraphs for sentiment, with truncation for long paragraphs
def classify_paragraph_sentiment(paragraph):
    # Truncate the paragraph if it is longer than the model's max length
    max_length = sentiment_tokenizer.model_max_length
    tokens = sentiment_tokenizer.tokenize(paragraph)
    if len(tokens) > max_length:
        tokens = tokens[:max_length]
        paragraph = sentiment_tokenizer.convert_tokens_to_string(tokens)
    
    result = sentiment_pipeline(paragraph)
    label = result[0]['label']  # Get the label directly as string
    score = result[0]['score']
    return label, score

# Apply the sentiment classification to the earnings calls dataframes
def apply_sentiment(df):
    df['sentiment_label'], df['sentiment_score'] = zip(*df['paragraph'].apply(classify_paragraph_sentiment))
    return df

# Apply the sentiment classification to both 'yes' datasets
earnings_st_james_yes_df = apply_sentiment(earnings_st_james_yes_df)
earnings_traveler_yes_df = apply_sentiment(earnings_traveler_yes_df)

# %%
earnings_traveler_yes_df
# Out:
#                                             file_name        date  \
# 0   cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 1   cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 2   cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 3   cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# 4   cleaned_Travelers Cos IncThe Earnings Call 201...  2019-10-22
# ..                                                ...         ...
# 65  cleaned_Travelers Cos IncThe Earnings Call 202...  2023-04-19
# 66  cleaned_Travelers Cos IncThe Earnings Call 202...  2023-07-20
# 67  cleaned_Travelers Cos IncThe Earnings Call 202...  2023-07-20
# 68  cleaned_Travelers Cos IncThe Earnings Call 202...  2024-01-19
# 69  cleaned_Travelers Cos IncThe Earnings Call 202...  2024-04-17
#
#                                                 token  \
# 0                    ['context', 'range', 'progress']
# 1   ['charge', 'evaluation', 'evaluation', 'favora...
# 2   ['execution', 'marketplace', 'policy', 'force'...
# 3   ['response', 'nature', 'degree', 'selection', ...
# 4   ['decision', 'takeaway', 'room', 'evidence', '...
# ..                                                ...
# 65  ['headwind', 'release', 'expectation', 'umbrel...
# 66  ['response', 'headwind', 'condition', 'reward'...
# 67  ['pattern', 'mix', 'shift', 'threshold', 'magn...
# 68  ['extent', 'estimation', 'estimation', 'expect...
# 69  ['row', 'digit', 'couple', 'needle', 'volatili...
#
#                                             paragraph sentiment_label  \
# 0   In terms of weather, non-catastrophe weather-r...            risk
# 1   You may also notice that we have a small charg...         neutral
# 2   Thanks, Tom. And good morning, everyone. In Pe...            risk
# 3   Larry, in response to that, given the environm...            risk
# 4   Yeah. Paul, again, we're executing one account...         neutral
# ..                                                ...             ...
# 65  Cognizant results were good. But just curious,...            risk
# 66  In terms of pricing, we're pleased with our re...     opportunity
# 67  Okay, perfect. That's helpful. And ﬁnal questi...            risk
# 68  To a lesser extent, it also beneﬁted from the ...         neutral
# 69  Renewal rate change remained high, coming in a...     opportunity
#
#     sentiment_score
# 0          0.807914
# 1          0.928970
# 2          0.405356
# 3          0.780956
# 4          0.769709
# ..              ...
# 65         0.564817
# 66         0.483056
# 67         0.941546
# 68         0.453462
# 69         0.548817
#
# [70 rows x 6 columns]

# %%
earnings_st_james_yes_df
# Out:
#                                             file_name        date  \
# 0   cleaned_St James_s Place PLC Earnings Call 201...  2019-07-31
# 1   cleaned_St James_s Place PLC Earnings Call 202...  2020-02-27
# 2   cleaned_St James_s Place PLC Earnings Call 202...  2020-07-28
# 3   cleaned_St James_s Place PLC Earnings Call 202...  2020-07-28
# 4   cleaned_St James_s Place PLC Earnings Call 202...  2020-07-28
# 5   cleaned_St James_s Place PLC Earnings Call 202...  2020-07-28
# 6   cleaned_St James_s Place PLC Earnings Call 202...  2021-02-25
# 7   cleaned_St James_s Place PLC Earnings Call 202...  2021-02-25
# 8   cleaned_St James_s Place PLC Earnings Call 202...  2022-02-24
# 9   cleaned_St James_s Place PLC Earnings Call 202...  2022-02-24
# 10  cleaned_St James_s Place PLC Earnings Call 202...  2022-02-24
# 11  cleaned_St James_s Place PLC Earnings Call 202...  2022-02-24
# 12  cleaned_St James_s Place PLC Earnings Call 202...  2022-02-24
# 13  cleaned_St James_s Place PLC Earnings Call 202...  2022-07-28
# 14  cleaned_St James_s Place PLC Earnings Call 202...  2022-07-28
# 15  cleaned_St James_s Place PLC Earnings Call 202...  2023-02-28
# 16  cleaned_St James_s Place PLC Earnings Call 202...  2023-07-27
# 17  cleaned_St James_s Place PLC Earnings Call 202...  2024-02-28
# 18  cleaned_St James_s Place PLC Earnings Call 202...  2024-02-28
#
#                                                 token  \
# 0   ['infrastructure', 'oﬃce', 'city', 'oﬃce', 'fu...
# 1   ['proposition', 'hand', 'manager', 'strategy',...
# 2   ['concern', 'mechanism', 'consumer', 'comment'...
# 3   ['context', 'owner', 'owner', 'size', 'owner',...
# 4   ['equity', 'building', 'block', 'carbon', 'car...
# 5   ['technique', 'algorithm', 'ai', 'machine', 'l...
# 6   ['disclosure', 'invest', 'launch', 'report', '...
# 7                         ['driver', 'sky', 'driver']
# 8   ['proposition', 'security', 'proposition', 'pr...
# 9   ['owner', 'proposition', 'carbon', 'report', '...
# 10  ['framework', 'principle', 'community', 'clima...
# 11  ['normalization', 'ﬁgure', 'pattern', 'withdra...
# 12  ['mixture', 'portfolio', 'winner', 'loser', 'p...
# 13  ['overhead', 'onset', 'commitment', 'visibilit...
# 14  ['allocation', 'job', 'job', 'job', 'job', 'go...
# 15  ['climate', 'signatory', 'reduction', 'carbon'...
# 16  ['culture', 'strategy', 'community', 'understa...
# 17  ['instance', 'role', 'pothole', 'bump', 'size'...
# 18  ['suspicion', 'hope', 'expectation', 'shoot', ...
#
#                                             paragraph sentiment_label  \
# 0   Increasing the partnership requires continuing...     opportunity
# 1   Our proposition as you can see on the left han...     opportunity
# 2   FSCS costs are GBP27.8 million, remain an incr...            risk
# 3   To put it into context, SJP as an asset owner ...     opportunity
# 4   And so going forward, we're going to have four...     opportunity
# 5   And then in terms of asset management. This is...         neutral
# 6   We've also progressed our client disclosures a...         neutral
# 7   Can you give us the drivers of this? And then ...         neutral
# 8   But we need to provide the proposition for our...     opportunity
# 9   We were one of the ﬁrst UK asset owners to sig...         neutral
# 10  With that, we'll spend time agreeing a respons...         neutral
# 11  Yeah. The normalization, it's very diﬃcult to ...         neutral
# 12  Thank you, Craig. Rob, if you want to come bac...     opportunity
# 13  Yeah, hi, Andy. So 2022, you're quite right. W...         neutral
# 14  In terms of asset allocation, that's our job a...     opportunity
# 15  Climate change is one such area. And as a sign...         neutral
# 16  Finally, on our culture on being a leading res...     opportunity
# 17  Third instance, anything else, Mark? Look, I'v...         neutral
# 18  And my personal suspicion is rates will come d...     opportunity
#
#     sentiment_score
# 0          0.976124
# 1          0.652018
# 2          0.714761
# 3          0.909023
# 4          0.944053
# 5          0.600051
# 6          0.878304
# 7          0.509702
# 8          0.737101
# 9          0.728445
# 10         0.867718
# 11         0.572213
# 12         0.590074
# 13         0.905036
# 14         0.919178
# 15         0.869121
# 16         0.969220
# 17         0.806734
# 18         0.464043

# %% [markdown]
# ## Visualisations

# %% [markdown]
# ### Visualising the Distribution of TCFD Recommendation Categories Over Time

# %% [markdown]
# This visualization displays the percentage distribution of paragraphs classified into TCFD recommendation categories for the companies St. James and Traveler Cos over the years. The paragraphs are categorized into governance, strategy, risk management, metrics and targets and non-climate-related classes. The stacked bar chart provides a clear, year-by-year breakdown of how these categories are represented, allowing for easy comparison of trends and shifts in reporting emphasis.

# %%
def plot_tcfd_distribution(df, company_name, colors):
    # Create a pivot table for plotting
    pivot_table = df.pivot_table(index='date', columns='tcfd_classification_label', aggfunc='size', fill_value=0)
    
    # Convert counts to percentages
    pivot_table_percentage = pivot_table.div(pivot_table.sum(axis=1), axis=0) * 100
    
    # Plotting
    fig, ax = plt.subplots(figsize=(12, 8))
    pivot_table_percentage.plot(kind='bar', stacked=True, ax=ax, color=[colors[label] for label in pivot_table_percentage.columns])
    
    # Formatting
    ax.set_xlabel('Year')
    ax.set_ylabel('Percentage of Paragraphs')
    ax.set_title(f'Distribution of TCFD Recommendation Categories Over the Years for {company_name}')
    ax.grid(False)  # Remove grid
    
    # Add percentage labels to the bars
    for p in ax.patches:
        width = p.get_width()
        height = p.get_height()
        x, y = p.get_xy()
        if height > 0:
            ax.annotate(f'{height:.1f}%', (x + width / 2, y + height / 2), ha='center', va='center', fontsize=9, color='black')
    
    # Move the legend outside the plot
    ax.legend(title='TCFD Category', bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.tight_layout()
    plt.show()

# Define a consistent color palette for TCFD categories
colors = {
    'none': '#cccccc',       # Light gray for 'none'
    'metrics': '#1f77b4',    # Blue
    'strategy': '#ff7f0e',   # Orange
    'risk': '#2ca02c',       # Green
    'governance': '#d62728'  # Red
}

# Plot for St. James
plot_tcfd_distribution(tcfd_st_james_df, "St. James", colors)

# Plot for Traveler Cos
plot_tcfd_distribution(tcfd_traveler_df, "Traveler Cos", colors)

# %% [markdown]
# ### Percentage of Climate-Related Earnings Calls Texts Over the Years

# %% [markdown]
# This visualization illustrates the percentage of climate-related paragraphs in Bloomberg earnings calls for St. James and Traveler Cos from 2019 onwards. The bars represent the proportion of climate-related text each year, with annotations showing the exact percentages.

# %%
# Convert date to datetime to extract the year
earnings_st_james_df['date'] = pd.to_datetime(earnings_st_james_df['date'])
earnings_traveler_df['date'] = pd.to_datetime(earnings_traveler_df['date'])
earnings_st_james_yes_df['date'] = pd.to_datetime(earnings_st_james_yes_df['date'])
earnings_traveler_yes_df['date'] = pd.to_datetime(earnings_traveler_yes_df['date'])

earnings_st_james_df['year'] = earnings_st_james_df['date'].dt.year
earnings_traveler_df['year'] = earnings_traveler_df['date'].dt.year
earnings_st_james_yes_df['year'] = earnings_st_james_yes_df['date'].dt.year
earnings_traveler_yes_df['year'] = earnings_traveler_yes_df['date'].dt.year

# Calculate the total paragraphs per year
total_paragraphs_st_james = earnings_st_james_df.groupby('year').size().reset_index(name='total_paragraphs')
total_paragraphs_traveler = earnings_traveler_df.groupby('year').size().reset_index(name='total_paragraphs')

# Calculate the climate-related paragraphs per year
climate_paragraphs_st_james = earnings_st_james_yes_df.groupby('year').size().reset_index(name='climate_paragraphs')
climate_paragraphs_traveler = earnings_traveler_yes_df.groupby('year').size().reset_index(name='climate_paragraphs')

# Merge the dataframes
st_james_merged = pd.merge(total_paragraphs_st_james, climate_paragraphs_st_james, on='year', how='left').fillna(0)
traveler_merged = pd.merge(total_paragraphs_traveler, climate_paragraphs_traveler, on='year', how='left').fillna(0)

# Calculate the percentage of climate-related paragraphs
st_james_merged['percentage_climate_related'] = (st_james_merged['climate_paragraphs'] / st_james_merged['total_paragraphs']) * 100
traveler_merged['percentage_climate_related'] = (traveler_merged['climate_paragraphs'] / traveler_merged['total_paragraphs']) * 100

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.35
years = st_james_merged['year']

# Bar positions
index = range(len(years))
bar1 = ax.bar(index, st_james_merged['percentage_climate_related'], bar_width, label='St. James')
bar2 = ax.bar([i + bar_width for i in index], traveler_merged['percentage_climate_related'], bar_width, label='Traveler Cos')

# Adding the percentage labels on top of the bars
for bar in bar1:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

for bar in bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

# Customizing the plot
ax.set_xlabel('Year')
ax.set_ylabel('Percentage of Climate-Related Paragraphs')
ax.set_title('Percentage of Climate-Related Text Over the Years by Company (Bloomberg Earnings Calls)')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(years)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sentiment Climate Distribution of Bloomberg Earnings Calls

# %% [markdown]
# The visualizations illustrate the sentiment distribution of climate-related paragraphs within Bloomberg earnings calls for St. James and Traveler Cos across different years. The pie charts display the proportion of paragraphs categorized as "neutral," "opportunity," and "risk" for each year. This analysis helps to understand the evolution of climate-related sentiment in the companies' earnings calls over time.

# %%
def plot_sentiment_pie_charts(df, company_name):
    # Extract year from date and add as a new column
    df['year'] = pd.to_datetime(df['date']).dt.year

    # Get the unique years
    years = sorted(df['year'].unique())

    # Determine grid layout
    n_years = len(years)
    cols = 3  # Number of columns per row
    rows = (n_years + cols - 1) // cols  # Calculate rows needed

    # Set up the plot grid
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 7, rows * 8))
    fig.suptitle(f'Sentiment Climate Distribution of Bloomberg Earnings Calls for {company_name}', fontsize=18)

    if rows * cols > 1:
        axes = axes.flatten()
    else:
        axes = [axes]

    # Define a custom color palette
    colors = {
        'neutral': '#1f77b4',     # Blue
        'opportunity': '#ff7f0e', # Orange
        'risk': '#ffbb78'         # Yellow
    }

    # Iterate through years and axes
    for ax, year in zip(axes, years):
        # Filter data for the specific year
        yearly_data = df[df['year'] == year]

        # Count occurrences of each sentiment label
        sentiment_counts = yearly_data['sentiment_label'].value_counts()

        # Plot the pie chart
        wedges, texts, autotexts = ax.pie(
            sentiment_counts,
            autopct='%1.1f%%',
            startangle=140,
            colors=[colors[label] for label in sentiment_counts.index]
        )

        # Add the year above the pie chart
        ax.text(0, 1.2, str(year), ha='center', va='center', fontsize=16, fontweight='bold')

        # Add labels outside the pie chart
        ax.legend(wedges, [f'{label} ({count})' for label, count in sentiment_counts.items()], loc='upper right')

    # Hide unused axes
    for ax in axes[n_years:]:
        ax.axis('off')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# Plot for St. James
plot_sentiment_pie_charts(earnings_st_james_yes_df, "St. James")

# Plot for Traveler Cos
plot_sentiment_pie_charts(earnings_traveler_yes_df, "Traveler Cos")

# %% [markdown]
# ### Earnings Calls and TCFD Main Labels Over Time

# %% [markdown]
# This visualization highlights the most frequent sentiment labels from earnings calls and TCFD reports for St. James and Traveler Cos from 2019 onwards. Each point on the plot represents a sentiment label—neutral, opportunity, or risk—associated with the dates of the earnings call transcripts. The vertical red dashed lines mark the years, with corresponding TCFD labels provided, showcasing the company's focus. This view allows for a clear comparison between the TCFD strategies and the topics discussed during the earnings calls for each company.

# %%
# Function to get the most frequent label for each file
def get_most_frequent_labels_with_date(df, label_col, file_col, date_col):
    most_frequent_labels = []

    # Iterate over each file
    for file_name in df[file_col].unique():
        file_df = df[df[file_col] == file_name]
        
        # Check if the DataFrame is empty
        if file_df.empty:
            continue
        
        # Extract the date information
        most_recent_date = file_df[date_col].max() if date_col in file_df.columns else None
        
        # Count occurrences of each label
        label_counts = file_df[label_col].value_counts()
        
        # Check if there are any labels counted
        if not label_counts.empty:
            # Get the most frequent label
            most_frequent_label = label_counts.idxmax()
            most_frequent_labels.append([file_name, most_recent_date, most_frequent_label, label_counts[most_frequent_label]])

    # Create DataFrame from the results
    most_frequent_labels_df = pd.DataFrame(most_frequent_labels, columns=[file_col, 'most_recent_date', 'most_frequent_label', 'count'])
    return most_frequent_labels_df

# Count sentiment labels for each file
earnings_st_james_most_frequent = get_most_frequent_labels_with_date(earnings_st_james_yes_df, 'sentiment_label', 'file_name', 'date')
earnings_traveler_most_frequent = get_most_frequent_labels_with_date(earnings_traveler_yes_df, 'sentiment_label', 'file_name', 'date')

# Count TCFD classification labels for each file
tcfd_st_james_most_frequent = get_most_frequent_labels_with_date(tcfd_st_james_df, 'tcfd_classification_label', 'file_name', 'date')
tcfd_traveler_most_frequent = get_most_frequent_labels_with_date(tcfd_traveler_df, 'tcfd_classification_label', 'file_name', 'date')

# %%
# Define color mapping for sentiment labels
label_color_mapping = {
    'neutral': 'blue',
    'opportunity': 'green',
    'risk': 'orange'
}

# Function to convert TCFD years to datetime
def convert_tcfd_date(df, date_col):
    df[date_col] = pd.to_datetime(df[date_col].astype(str) + '-01-01', utc=False)
    return df

# Function to ensure all dates are timezone-naive
def make_dates_timezone_naive(df, date_col):
    df[date_col] = df[date_col].dt.tz_localize(None)
    return df

# Function to plot the most frequent labels over time
def plot_labels_over_time(tcfd_data, earnings_data, company_name):
    fig, ax = plt.subplots(figsize=(20, 10))

    # Convert the 'most_recent_date' in TCFD data to datetime and ensure dates are timezone-naive
    tcfd_data = convert_tcfd_date(tcfd_data, 'most_recent_date')
    tcfd_data = make_dates_timezone_naive(tcfd_data, 'most_recent_date')
    earnings_data = make_dates_timezone_naive(earnings_data, 'most_recent_date')

    # Plot TCFD Labels
    for i, row in tcfd_data.iterrows():
        ax.axvline(x=row['most_recent_date'], color='red', linestyle='--')
        # Adjusting the text properties: rotation=90, fontsize=14, weight='bold', ha='center', va='center'
        ax.text(row['most_recent_date'], 0.5, row['most_frequent_label'], color='black', fontsize=14, weight='bold', ha='center', va='center', rotation=90, bbox=dict(facecolor='white', edgecolor='none', boxstyle='round,pad=0.5'))

    # Plot Earnings Calls
    for i, row in earnings_data.iterrows():
        label_color = label_color_mapping.get(row['most_frequent_label'], 'blue')
        ax.scatter(row['most_recent_date'], row['most_frequent_label'], color=label_color, label='Earnings Call', s=100, zorder=5)
        ax.text(row['most_recent_date'], row['most_frequent_label'], row['most_recent_date'].strftime("%Y-%m-%d"), color='black', fontsize=8, ha='center', va='top', rotation=45)

    # Formatting
    ax.set_xlabel('TCFD Main Label / Date')
    ax.set_ylabel('Earnings Call Main Label')
    ax.set_yticks(sorted(set(earnings_data['most_frequent_label'])))
    ax.set_yticklabels(sorted(set(earnings_data['most_frequent_label'])))
    ax.set_title(f'Most Frequent Labels Over Time for {company_name}')
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)

    # Adjust y-limits to provide space for Earnings labels
    ax.set_ylim(-1, len(set(earnings_data['most_frequent_label'])))

    # Set x-limits based on the date range in the data
    min_date = min(tcfd_data['most_recent_date'].min(), earnings_data['most_recent_date'].min())
    max_date = max(tcfd_data['most_recent_date'].max(), earnings_data['most_recent_date'].max())
    ax.set_xlim(min_date - pd.DateOffset(months=6), max_date + pd.DateOffset(months=6))

    plt.tight_layout()
    plt.show()

# Convert 'most_recent_date' in TCFD DataFrames before plotting
tcfd_st_james_most_frequent = convert_tcfd_date(tcfd_st_james_most_frequent, 'most_recent_date')
tcfd_traveler_most_frequent = convert_tcfd_date(tcfd_traveler_most_frequent, 'most_recent_date')

# Plot for St. James
plot_labels_over_time(tcfd_st_james_most_frequent, earnings_st_james_most_frequent, "St. James")

# Plot for Traveler Cos
plot_labels_over_time(tcfd_traveler_most_frequent, earnings_traveler_most_frequent, "Traveler Cos")
# Out:
# C:\Users\dimi3\AppData\Local\Temp\ipykernel_22444\1031849520.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col] = pd.to_datetime(df[date_col].astype(str) + '-01-01', utc=False)
# C:\Users\dimi3\AppData\Local\Temp\ipykernel_22444\1031849520.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col] = pd.to_datetime(df[date_col].astype(str) + '-01-01', utc=False)
